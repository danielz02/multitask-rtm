# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import sys  
sys.path.insert(0, '/content/gdrive/MyDrive/crop_science/aws-cv-task2vec-master')

# %%
from task2vec import Task2Vec
from models import get_model
import datasets
import task_similarity

# %%
dataset_names = ('stl10', 'mnist', 'cifar10', 'cifar100', 'letters', 'kmnist')
# Change `root` with the directory you want to use to download the datasets
dataset_list = [datasets.__dict__[name](root='/content/gdrive/MyDrive/crop_science/aws-cv-task2vec-master/data')[0] for name in dataset_names]
# Out:
# Downloading http://ai.stanford.edu/~acoates/stl10/stl10_binary.tar.gz to /content/gdrive/MyDrive/crop_science/aws-cv-task2vec-master/data/stl10_binary.tar.gz
#   0%|          | 0/2640397119 [00:00<?, ?it/s]
# Extracting /content/gdrive/MyDrive/crop_science/aws-cv-task2vec-master/data/stl10_binary.tar.gz to /content/gdrive/MyDrive/crop_science/aws-cv-task2vec-master/data
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to /content/gdrive/MyDrive/crop_science/aws-cv-task2vec-master/data/MNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting /content/gdrive/MyDrive/crop_science/aws-cv-task2vec-master/data/MNIST/raw/train-images-idx3-ubyte.gz to /content/gdrive/MyDrive/crop_science/aws-cv-task2vec-master/data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to /content/gdrive/MyDrive/crop_science/aws-cv-task2vec-master/data/MNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting /content/gdrive/MyDrive/crop_science/aws-cv-task2vec-master/data/MNIST/raw/train-labels-idx1-ubyte.gz to /content/gdrive/MyDrive/crop_science/aws-cv-task2vec-master/data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to /content/gdrive/MyDrive/crop_science/aws-cv-task2vec-master/data/MNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting /content/gdrive/MyDrive/crop_science/aws-cv-task2vec-master/data/MNIST/raw/t10k-images-idx3-ubyte.gz to /content/gdrive/MyDrive/crop_science/aws-cv-task2vec-master/data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to /content/gdrive/MyDrive/crop_science/aws-cv-task2vec-master/data/MNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting /content/gdrive/MyDrive/crop_science/aws-cv-task2vec-master/data/MNIST/raw/t10k-labels-idx1-ubyte.gz to /content/gdrive/MyDrive/crop_science/aws-cv-task2vec-master/data/MNIST/raw
#
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to /content/gdrive/MyDrive/crop_science/aws-cv-task2vec-master/data/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting /content/gdrive/MyDrive/crop_science/aws-cv-task2vec-master/data/cifar-10-python.tar.gz to /content/gdrive/MyDrive/crop_science/aws-cv-task2vec-master/data
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to /content/gdrive/MyDrive/crop_science/aws-cv-task2vec-master/data/cifar-100-python.tar.gz
#   0%|          | 0/169001437 [00:00<?, ?it/s]
# Extracting /content/gdrive/MyDrive/crop_science/aws-cv-task2vec-master/data/cifar-100-python.tar.gz to /content/gdrive/MyDrive/crop_science/aws-cv-task2vec-master/data
# Downloading https://www.itl.nist.gov/iaui/vip/cs_links/EMNIST/gzip.zip to /content/gdrive/MyDrive/crop_science/aws-cv-task2vec-master/data/EMNIST/raw/gzip.zip
#   0%|          | 0/561753746 [00:00<?, ?it/s]
# Extracting /content/gdrive/MyDrive/crop_science/aws-cv-task2vec-master/data/EMNIST/raw/gzip.zip to /content/gdrive/MyDrive/crop_science/aws-cv-task2vec-master/data/EMNIST/raw
# Downloading http://codh.rois.ac.jp/kmnist/dataset/kmnist/train-images-idx3-ubyte.gz
# Downloading http://codh.rois.ac.jp/kmnist/dataset/kmnist/train-images-idx3-ubyte.gz to /content/gdrive/MyDrive/crop_science/aws-cv-task2vec-master/data/KMNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/18165135 [00:00<?, ?it/s]
# Extracting /content/gdrive/MyDrive/crop_science/aws-cv-task2vec-master/data/KMNIST/raw/train-images-idx3-ubyte.gz to /content/gdrive/MyDrive/crop_science/aws-cv-task2vec-master/data/KMNIST/raw
#
# Downloading http://codh.rois.ac.jp/kmnist/dataset/kmnist/train-labels-idx1-ubyte.gz
# Downloading http://codh.rois.ac.jp/kmnist/dataset/kmnist/train-labels-idx1-ubyte.gz to /content/gdrive/MyDrive/crop_science/aws-cv-task2vec-master/data/KMNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/29497 [00:00<?, ?it/s]
# Extracting /content/gdrive/MyDrive/crop_science/aws-cv-task2vec-master/data/KMNIST/raw/train-labels-idx1-ubyte.gz to /content/gdrive/MyDrive/crop_science/aws-cv-task2vec-master/data/KMNIST/raw
#
# Downloading http://codh.rois.ac.jp/kmnist/dataset/kmnist/t10k-images-idx3-ubyte.gz
# Downloading http://codh.rois.ac.jp/kmnist/dataset/kmnist/t10k-images-idx3-ubyte.gz to /content/gdrive/MyDrive/crop_science/aws-cv-task2vec-master/data/KMNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/3041136 [00:00<?, ?it/s]
# Extracting /content/gdrive/MyDrive/crop_science/aws-cv-task2vec-master/data/KMNIST/raw/t10k-images-idx3-ubyte.gz to /content/gdrive/MyDrive/crop_science/aws-cv-task2vec-master/data/KMNIST/raw
#
# Downloading http://codh.rois.ac.jp/kmnist/dataset/kmnist/t10k-labels-idx1-ubyte.gz
# Downloading http://codh.rois.ac.jp/kmnist/dataset/kmnist/t10k-labels-idx1-ubyte.gz to /content/gdrive/MyDrive/crop_science/aws-cv-task2vec-master/data/KMNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/5120 [00:00<?, ?it/s]
# Extracting /content/gdrive/MyDrive/crop_science/aws-cv-task2vec-master/data/KMNIST/raw/t10k-labels-idx1-ubyte.gz to /content/gdrive/MyDrive/crop_science/aws-cv-task2vec-master/data/KMNIST/raw

# %%
type(dataset_list[2])
# Out:
# torchvision.datasets.cifar.CIFAR10

# %%
embeddings = []
for name, dataset in zip(dataset_names, dataset_list):
    print(f"Embedding {name}")
    probe_network = get_model('resnet34', pretrained=True, num_classes=int(max(dataset.targets)+1)).cuda()
    embeddings.append( Task2Vec(probe_network, max_samples=1000, skip_layers=6).embed(dataset) )
# Out:
# Embedding stl10
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:252: UserWarning: Accessing the model URLs via the internal dictionary of the module is deprecated since 0.13 and may be removed in the future. Please access them via the appropriate Weights Enum instead.
#   warnings.warn(
# Downloading: "https://download.pytorch.org/models/resnet34-b627a593.pth" to /root/.cache/torch/hub/checkpoints/resnet34-b627a593.pth
#   0%|          | 0.00/83.3M [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-6-53d2b40959d4> in <module>
#       2 for name, dataset in zip(dataset_names, dataset_list):
#       3     print(f"Embedding {name}")
# ----> 4     probe_network = get_model('resnet34', pretrained=True, num_classes=int(max(dataset.targets)+1)).cuda()
#       5     embeddings.append( Task2Vec(probe_network, max_samples=1000, skip_layers=6).embed(dataset) )
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in cuda(self, device)
#     747             Module: self
#     748         """
# --> 749         return self._apply(lambda t: t.cuda(device))
#     750
#     751     def ipu(self: T, device: Optional[Union[int, device]] = None) -> T:
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _apply(self, fn)
#     639     def _apply(self, fn):
#     640         for module in self.children():
# --> 641             module._apply(fn)
#     642
#     643         def compute_should_use_set_data(tensor, tensor_applied):
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _apply(self, fn)
#     662             # `with torch.no_grad():`
#     663             with torch.no_grad():
# --> 664                 param_applied = fn(param)
#     665             should_use_set_data = compute_should_use_set_data(param, param_applied)
#     666             if should_use_set_data:
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in <lambda>(t)
#     747             Module: self
#     748         """
# --> 749         return self._apply(lambda t: t.cuda(device))
#     750
#     751     def ipu(self: T, device: Optional[Union[int, device]] = None) -> T:
#
# /usr/local/lib/python3.8/dist-packages/torch/cuda/__init__.py in _lazy_init()
#     227         if 'CUDA_MODULE_LOADING' not in os.environ:
#     228             os.environ['CUDA_MODULE_LOADING'] = 'LAZY'
# --> 229         torch._C._cuda_init()
#     230         # Some of the queued calls may reentrantly call _lazy_init();
#     231         # we need to just return without initializing in that case.
#
# RuntimeError: No CUDA GPUs are available

# %%
task_similarity.plot_distance_matrix(embeddings, dataset_names)
